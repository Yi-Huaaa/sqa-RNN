# %%
import tensorflow as tf
from TrainingRNN_1DTFIM import run_1DTFIM

#numsteps = number of training iterations
#systemsize = number of physical spins
#Bx = transverse magnetic field
#numsamples = number of samples used for training
numsamples = 200
#num_units = number of memory units of the hidden state of the RNN
#num_layers = number of vertically stacked RNN cells

'''
RNNcells = [
        tf.keras.layers.SimpleRNNCell,
        tf.keras.layers.GRUCell,
        tf.keras.layers.LSTMCell,
]
2 4 0 1
activationFunctions = [
    v tf.nn.elu,
    v tf.keras.activations.elu,
    v tf.keras.activations.relu,
    x tf.keras.activations.deserialize,
    v tf.keras.activations.exponential,
    x tf.keras.activations.hard_sigmoid,
    x tf.keras.activations.selu,
    x tf.keras.activations.sigmoid,
    v tf.keras.activations.softsign
]
activationFunctions = [
    tf.keras.activations.elu, 
    tf.keras.activations.relu,
    tf.keras.activations.exponential,
    tf.keras.activations.sigmoid,
    tf.keras.activations.softsign
]
'''

#This function trains a pRNN wavefunction for 1DTFIM with the corresponding hyperparams
RNNEnergy_cell_0, varRNNEnergy_cell_0 = run_1DTFIM(RNNtype = 0, activationType = 0, numsteps = 100, systemsize = 32, Bx = +2, num_units = 40,  num_layers = 1, numsamples = 50, learningrate = 5e-4, seed = 111)
RNNEnergy_cell_1, varRNNEnergy_cell_1 = run_1DTFIM(RNNtype = 0, activationType = 1, numsteps = 100, systemsize = 32, Bx = +2, num_units = 40,  num_layers = 1, numsamples = 50, learningrate = 5e-4, seed = 111)
RNNEnergy_cell_2, varRNNEnergy_cell_2 = run_1DTFIM(RNNtype = 0, activationType = 2, numsteps = 100, systemsize = 32, Bx = +2, num_units = 40,  num_layers = 1, numsamples = 50, learningrate = 5e-4, seed = 111)
RNNEnergy_cell_3, varRNNEnergy_cell_3 = run_1DTFIM(RNNtype = 0, activationType = 3, numsteps = 100, systemsize = 32, Bx = +2, num_units = 40,  num_layers = 1, numsamples = 50, learningrate = 5e-4, seed = 111)
RNNEnergy_cell_4, varRNNEnergy_cell_4 = run_1DTFIM(RNNtype = 0, activationType = 4, numsteps = 100, systemsize = 32, Bx = +2, num_units = 40,  num_layers = 1, numsamples = 50, learningrate = 5e-4, seed = 111)
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.SimpleRNNCell'>
# activation Functions <function elu at 0x7f27c79f5048>
# mean(E): -59.783399384730586, var(E): 54.81622811318318, #samples 50, #Step 0
#
#
# mean(E): -64.64450018101502, var(E): 19.257261562455227, #samples 50, #Step 10
#
#
# mean(E): -65.23789346052737, var(E): 14.224061166525374, #samples 50, #Step 20
#
#
# mean(E): -67.4154406173687, var(E): 5.402925507830276, #samples 50, #Step 30
#
#
# mean(E): -67.40020807596221, var(E): 5.440681449220051, #samples 50, #Step 40
#
#
# mean(E): -67.29935688006218, var(E): 1.9243678836366098, #samples 50, #Step 50
#
#
# mean(E): -67.50265227953905, var(E): 1.181036496995402, #samples 50, #Step 60
#
#
# mean(E): -67.74424662821328, var(E): 0.8891730251320084, #samples 50, #Step 70
#
#
# mean(E): -67.88746360879975, var(E): 0.6129542107727911, #samples 50, #Step 80
#
#
# mean(E): -67.79687024108055, var(E): 0.6293864922090475, #samples 50, #Step 90
#
#
# ...

# %%
min_RNNEnergy_cell_0 = min(RNNEnergy_cell_0)
print('min_RNNEnergy_cell_0 =', min_RNNEnergy_cell_0)
print('\n')

min_RNNEnergy_cell_1 = min(RNNEnergy_cell_1)
print('min_RNNEnergy_cell_1 =', min_RNNEnergy_cell_1)
print('\n')

min_RNNEnergy_cell_2 = min(RNNEnergy_cell_2)
print('min_RNNEnergy_cell_2 =', min_RNNEnergy_cell_2)
print('\n')

min_RNNEnergy_cell_3 = min(RNNEnergy_cell_3)
print('min_RNNEnergy_cell_3 =', min_RNNEnergy_cell_3)
print('\n')

min_RNNEnergy_cell_4 = min(RNNEnergy_cell_4)
print('min_RNNEnergy_cell_4 =', min_RNNEnergy_cell_4)
print('\n')
# Out:
# min_RNNEnergy_cell_0 = -68.07341008261476
#
#
# min_RNNEnergy_cell_1 = -68.08164673213412
#
#
# min_RNNEnergy_cell_2 = -68.07793069923113
#
#
# min_RNNEnergy_cell_3 = -68.08293627366143
#
#
# min_RNNEnergy_cell_4 = -68.08016464051744
