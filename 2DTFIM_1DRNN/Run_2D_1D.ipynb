# %% [markdown]
# # EXP2
# ## END!!
# ### 20210613 06:14 yhc

# %%
# check for cuda and python version 
import os, sys

print(os.environ['LD_LIBRARY_PATH'])
print(sys.version)
# Out:
# /home/yhc/cuda/lib64:/usr/local/cuda-11.2/lib64
# 3.6.9 (default, Jan 26 2021, 15:33:00)
# [GCC 8.4.0]

# %%
# Check for using gpu
import tensorflow as tf

print(tf.test.gpu_device_name())
print(tf.test.is_gpu_available())
print(tf.config.list_physical_devices('GPU'))
# Out:
# /device:GPU:0
# WARNING:tensorflow:From <ipython-input-1-f6d867d7ca84>:5: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # 實驗二、2D model 1D RNN find Best model for different number of spins

# %% [markdown]
# ## 實驗2-10x10, 20x20 換RNN type and actfunc

# %% [markdown]
# ### 實驗2-1-1. 10x10 spins, RNNtype, activate function

# %%
# 10x10, SimpleRNNCell 
import tensorflow as tf
from Training1DRNN_2DTFIM import run_2DTFIM

Energy_SimpRNN_elu, varEnergy_SimpRNN_elu                 = run_2DTFIM(RNNtype = 0, activationType = 0, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_SimpRNN_relu, varEnergy_SimpRNN_relu               = run_2DTFIM(RNNtype = 0, activationType = 1, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_SimpRNN_exponential, varEnergy_SimpRNN_exponential = run_2DTFIM(RNNtype = 0, activationType = 2, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_SimpRNN_sigmoid, varEnergy_SimpRNN_sigmoid         = run_2DTFIM(RNNtype = 0, activationType = 3, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)

# spins = 10x10
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.SimpleRNNCell'>
# activation Functions <function elu at 0x7fe44b50f488>
# mean(E): -109.13433244312078, var(E): 211.58731326406053, #samples 25, #Step 0
#
#
# mean(E): -110.80561310790335, var(E): 253.24307253339938, #samples 25, #Step 10
#
#
# mean(E): -127.8791109772238, var(E): 351.2958017020544, #samples 25, #Step 20
#
#
# mean(E): -138.82231870286247, var(E): 311.42678430884126, #samples 25, #Step 30
#
#
# mean(E): -148.07032432575113, var(E): 117.22041155276051, #samples 25, #Step 40
#
#
# mean(E): -158.5106812815503, var(E): 221.71640615462601, #samples 25, #Step 50
#
#
# mean(E): -168.22196654739196, var(E): 145.72632866390043, #samples 25, #Step 60
#
#
# mean(E): -172.65623813423753, var(E): 64.20175781830895, #samples 25, #Step 70
#
#
# mean(E): -176.73525608977164, var(E): 42.639380623809195, #samples 25, #Step 80
#
#
# mean(E): -181.09177826966084, var(E): 64.20056416962788, #samples 25, #Step 90
#
#
# ...

# %%
import tensorflow as tf
from Training1DRNN_2DTFIM import run_2DTFIM

Energy_GRUCell_elu, varEnergy_GRUCell_elu                 = run_2DTFIM(RNNtype = 1, activationType = 0, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_GRUCell_relu, varEnergy_GRUCell_relu               = run_2DTFIM(RNNtype = 1, activationType = 1, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_GRUCell_exponential, varEnergy_GRUCell_exponential = run_2DTFIM(RNNtype = 1, activationType = 2, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_GRUCell_sigmoid, varEnergy_GRUCell_sigmoid         = run_2DTFIM(RNNtype = 1, activationType = 3, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.GRUCell'>
# activation Functions <function elu at 0x7fe44b50f488>
# mean(E): -103.392097497117, var(E): 243.57104243825822, #samples 25, #Step 0
#
#
# mean(E): -102.94973535960357, var(E): 175.15758783497444, #samples 25, #Step 10
#
#
# mean(E): -99.64030121337613, var(E): 147.4146764507814, #samples 25, #Step 20
#
#
# mean(E): -102.55315794732053, var(E): 181.81338813003447, #samples 25, #Step 30
#
#
# mean(E): -100.74583911803258, var(E): 126.82495462745166, #samples 25, #Step 40
#
#
# mean(E): -99.63489636279618, var(E): 255.33723259366005, #samples 25, #Step 50
#
#
# mean(E): -103.93824642209879, var(E): 182.21308430855413, #samples 25, #Step 60
#
#
# mean(E): -101.41755210061903, var(E): 136.85883381296807, #samples 25, #Step 70
#
#
# mean(E): -100.97084095926216, var(E): 107.44110978116872, #samples 25, #Step 80
#
#
# mean(E): -104.81771761332449, var(E): 128.5805248375949, #samples 25, #Step 90
#
#
# ...

# %%
import tensorflow as tf
from Training1DRNN_2DTFIM import run_2DTFIM

Energy_LSTMCell_elu, varEnergy_LSTM_elu                 = run_2DTFIM(RNNtype = 2, activationType = 0, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_LSTMCell_relu, varEnergy_LSTM_relu               = run_2DTFIM(RNNtype = 2, activationType = 1, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_LSTMCell_exponential, varEnergy_LSTM_exponential = run_2DTFIM(RNNtype = 2, activationType = 2, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_LSTMCell_sigmoid, varEnergy_LSTM_sigmoid         = run_2DTFIM(RNNtype = 2, activationType = 3, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.LSTMCell'>
# activation Functions <function elu at 0x7fe44b50f488>
# mean(E): -102.14469081428888, var(E): 213.1993154954607, #samples 25, #Step 0
#
#
# mean(E): -100.11125467685282, var(E): 167.2680608244873, #samples 25, #Step 10
#
#
# mean(E): -98.62224461901049, var(E): 157.6024990723453, #samples 25, #Step 20
#
#
# mean(E): -102.0067328339793, var(E): 184.4208653201045, #samples 25, #Step 30
#
#
# mean(E): -98.2084216101758, var(E): 123.47994589359276, #samples 25, #Step 40
#
#
# mean(E): -97.13426394721819, var(E): 248.13200031982822, #samples 25, #Step 50
#
#
# mean(E): -102.62957543350856, var(E): 179.11302912235692, #samples 25, #Step 60
#
#
# mean(E): -97.13279624636913, var(E): 113.06062140984577, #samples 25, #Step 70
#
#
# mean(E): -98.43859195315814, var(E): 138.73114642001258, #samples 25, #Step 80
#
#
# mean(E): -100.86156705379217, var(E): 108.10457120986283, #samples 25, #Step 90
#
#
# ...

# %%
# Simple RNN cell      
import numpy as np
min_Energy_SimpRNN_elu = min(Energy_SimpRNN_elu)
print("10x10 model:")
print('min_Energy_SimpRNN_elu', min_Energy_SimpRNN_elu)

min_Energy_SimpRNN_relu = min(Energy_SimpRNN_relu)
print('min_Energy_SimpRNN_relu', min_Energy_SimpRNN_relu)

min_Energy_SimpRNN_exponential = min(Energy_SimpRNN_exponential)
print('min_Energy_SimpRNN_exponential', min_Energy_SimpRNN_exponential)

min_Energy_SimpRNN_sigmoid = min(Energy_SimpRNN_sigmoid)
print('min_Energy_SimpRNN_sigmoid', min_Energy_SimpRNN_sigmoid)
print('\n')

# GRUCell cell      
import numpy as np

min_Energy_GRUCell_elu = min(Energy_GRUCell_elu)
print('min_Energy_GRUCell_elu', min_Energy_GRUCell_elu)

min_Energy_GRUCell_relu = min(Energy_GRUCell_relu)
print('min_Energy_GRUCell_relu', min_Energy_GRUCell_relu)

min_Energy_GRUCell_exponential = min(Energy_GRUCell_exponential)
print('min_Energy_GRUCell_exponential', min_Energy_GRUCell_exponential)

min_Energy_GRUCell_sigmoid = min(Energy_GRUCell_sigmoid)
print('min_Energy_GRUCell_sigmoid', min_Energy_GRUCell_sigmoid)
print('\n')

# LSTMCell cell      
import numpy as np

min_Energy_LSTMCell_elu = min(Energy_LSTMCell_elu)
print('min_Energy_LSTMCell_elu', min_Energy_LSTMCell_elu)

min_Energy_LSTMCell_relu = min(Energy_LSTMCell_relu)
print('min_Energy_LSTMCell_relu', min_Energy_LSTMCell_relu)

min_Energy_LSTMCell_exponential = min(Energy_LSTMCell_exponential)
print('min_Energy_LSTMCell_exponential', min_Energy_LSTMCell_exponential)

min_Energy_LSTMCell_sigmoid = min(Energy_LSTMCell_sigmoid)
print('min_Energy_LSTMCell_sigmoid', min_Energy_LSTMCell_sigmoid)
print('\n')
print('Best3:')
print('1. ')
print('2. ')
print('3. ')
# Out:
# 10x10 model:
# min_Energy_SimpRNN_elu -193.6881824591629
# min_Energy_SimpRNN_relu -193.6881824591629
# min_Energy_SimpRNN_exponential -193.6881824591629
# min_Energy_SimpRNN_sigmoid -193.6881824591629
#
#
# min_Energy_GRUCell_elu -193.91850990592033
# min_Energy_GRUCell_relu -193.91850990592033
# min_Energy_GRUCell_exponential -193.91850990592033
# min_Energy_GRUCell_sigmoid -193.91850990592033
#
#
# min_Energy_LSTMCell_elu -192.34199336314418
# min_Energy_LSTMCell_relu -192.34199336314418
# min_Energy_LSTMCell_exponential -192.34199336314418
# min_Energy_LSTMCell_sigmoid -192.34199336314418
#
#
# Best3:
# 1.
# 2.
# 3.

# %%
import numpy as np
#Computing the ground state energy by taking average over the last 200 iterations
numsamples = 25
print("Energy_SimpRNN_elu=", np.mean(Energy_SimpRNN_elu[-200:]), "+-", np.sqrt(np.max(varEnergy_SimpRNN_elu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_SimpRNN_relu=", np.mean(Energy_SimpRNN_relu[-200:]), "+-", np.sqrt(np.max(varEnergy_SimpRNN_relu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_SimpRNN_exponential=", np.mean(Energy_SimpRNN_exponential[-200:]), "+-", np.sqrt(np.max(varEnergy_SimpRNN_exponential[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_SimpRNN_sigmoid=", np.mean(Energy_SimpRNN_sigmoid[-200:]), "+-", np.sqrt(np.max(varEnergy_SimpRNN_sigmoid[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("\n")

print("Energy_GRUCell_elu=", np.mean(Energy_GRUCell_elu[-200:]), "+-", np.sqrt(np.max(varEnergy_GRUCell_elu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_GRUCell_relu=", np.mean(Energy_GRUCell_relu[-200:]), "+-", np.sqrt(np.max(varEnergy_GRUCell_relu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_GRUCell_exponential=", np.mean(Energy_GRUCell_exponential[-200:]), "+-", np.sqrt(np.max(varEnergy_GRUCell_exponential[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_GRUCell_sigmoid=", np.mean(Energy_GRUCell_sigmoid[-200:]), "+-", np.sqrt(np.max(varEnergy_GRUCell_sigmoid[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("\n")

print("Energy_LSTMCell_elu=", np.mean(Energy_LSTMCell_elu[-200:]), "+-", np.sqrt(np.max(varEnergy_LSTM_elu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_LSTMCell_relu=", np.mean(Energy_LSTMCell_relu[-200:]), "+-", np.sqrt(np.max(varEnergy_LSTM_relu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_LSTMCell_exponential=", np.mean(Energy_LSTMCell_exponential[-200:]), "+-", np.sqrt(np.max(varEnergy_LSTM_exponential[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_LSTMCell_sigmoid=", np.mean(Energy_LSTMCell_sigmoid[-200:]), "+-", np.sqrt(np.max(varEnergy_LSTM_sigmoid[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("\n")
# Out:
# Energy_SimpRNN_elu= -187.4247893219965 +- 0.09384430785714741
# Energy_SimpRNN_relu= -187.4247893219965 +- 0.09384430785714741
# Energy_SimpRNN_exponential= -187.4247893219965 +- 0.09384430785714741
# Energy_SimpRNN_sigmoid= -187.4247893219965 +- 0.09384430785714741
#
#
# Energy_GRUCell_elu= -173.43371401169912 +- 0.08107424775882988
# Energy_GRUCell_relu= -173.43371401169912 +- 0.08107424775882988
# Energy_GRUCell_exponential= -173.43371401169912 +- 0.08107424775882988
# Energy_GRUCell_sigmoid= -173.43371401169912 +- 0.08107424775882988
#
#
# Energy_LSTMCell_elu= -174.82865117039609 +- 0.08093088622767851
# Energy_LSTMCell_relu= -174.82865117039609 +- 0.08093088622767851
# Energy_LSTMCell_exponential= -174.82865117039609 +- 0.08093088622767851
# Energy_LSTMCell_sigmoid= -174.82865117039609 +- 0.08093088622767851

# %% [markdown]
# ### 實驗2-2-1 結果圖

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# 能量震盪收斂圖
rcParams['axes.labelsize']  = 20 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 20
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25

      
fig, ax = plt.subplots(figsize=(30, 10))
ax.plot(np.arange(1, len(Energy_SimpRNN_elu)+1), Energy_SimpRNN_elu, "vb--", label="SimpleRNN_elu")
ax.plot(np.arange(1, len(Energy_SimpRNN_relu)+1), Energy_SimpRNN_relu, "vb--",  label="SimpleRNN_sigmoid")
ax.plot(np.arange(1, len(Energy_SimpRNN_exponential)+1), Energy_SimpRNN_exponential, "vb--", label="SimpleRNN_exponential")
ax.plot(np.arange(1, len(Energy_SimpRNN_sigmoid)+1), Energy_SimpRNN_sigmoid, "vb--", label="SimpleRNN_sigmoid")

ax.plot(np.arange(1, len(Energy_GRUCell_elu)+1), Energy_GRUCell_elu, "sr:", label="GRUCell_elu")
ax.plot(np.arange(1, len(Energy_GRUCell_relu)+1), Energy_GRUCell_relu, "sr:",  label="GRUCell_sigmoid")
ax.plot(np.arange(1, len(Energy_GRUCell_exponential)+1), Energy_GRUCell_exponential, "sr:", label="GRUCell_exponential")
ax.plot(np.arange(1, len(Energy_GRUCell_sigmoid)+1), Energy_GRUCell_sigmoid, "sr:", label="GRUCell_sigmoid")

ax.plot(np.arange(1, len(Energy_LSTMCell_elu)+1), Energy_LSTMCell_elu, "og-", label="LSTMCell_elu")
ax.plot(np.arange(1, len(Energy_LSTMCell_relu)+1), Energy_LSTMCell_relu, "og-",  label="LSTMCell_relu")
ax.plot(np.arange(1, len(Energy_LSTMCell_exponential)+1), Energy_LSTMCell_exponential, "og-", label="LSTMCell_exponential")
ax.plot(np.arange(1, len(Energy_LSTMCell_sigmoid)+1), Energy_LSTMCell_sigmoid, "og-", label="LSTMCell_sigmoid")


plt.title("Energy prediction: 10x10 spins, 1D RNN model", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Predicted local Energy', fontsize = 25)
ax.set_xscale('log')
plt.legend()
plt.show()
print("\n")

# %%
# Variacnce plot
# spin = 32, 64, 128, 256
rcParams['axes.labelsize']  = 40 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 15 # 圖標的大小
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25


fig, ax = plt.subplots(figsize=(30,10))
ax.semilogy(np.arange(1, len(Energy_SimpRNN_elu)+1), varEnergy_SimpRNN_elu, "vb--", label="SimpleRNN_elu")
ax.semilogy(np.arange(1, len(Energy_SimpRNN_relu)+1), varEnergy_SimpRNN_relu, "vb--",  label="SimpleRNN_sigmoid")
ax.semilogy(np.arange(1, len(Energy_SimpRNN_exponential)+1), varEnergy_SimpRNN_exponential, "vb--", label="SimpleRNN_exponential")
ax.semilogy(np.arange(1, len(Energy_SimpRNN_sigmoid)+1), varEnergy_SimpRNN_sigmoid, "vb--", label="SimpleRNN_sigmoid")

ax.semilogy(np.arange(1, len(Energy_GRUCell_elu)+1), varEnergy_GRUCell_elu, "sr:", label="GRUCell_elu")
ax.semilogy(np.arange(1, len(Energy_GRUCell_relu)+1), varEnergy_GRUCell_relu, "sr:",  label="GRUCell_sigmoid")
ax.semilogy(np.arange(1, len(Energy_GRUCell_exponential)+1), varEnergy_GRUCell_exponential, "sr:", label="GRUCell_exponential")
ax.semilogy(np.arange(1, len(Energy_GRUCell_sigmoid)+1), Energy_GRUCell_sigmoid, "sr:", label="GRUCell_sigmoid")

ax.semilogy(np.arange(1, len(Energy_LSTMCell_elu)+1), varEnergy_LSTM_elu, "og-", label="LSTMCell_elu")
ax.semilogy(np.arange(1, len(Energy_LSTMCell_relu)+1), varEnergy_LSTM_relu, "og-",  label="LSTMCell_relu")
ax.semilogy(np.arange(1, len(Energy_LSTMCell_exponential)+1), varEnergy_LSTM_exponential, "og-", label="LSTMCell_exponential")
ax.semilogy(np.arange(1, len(Energy_LSTMCell_sigmoid)+1), varEnergy_LSTM_sigmoid, "og-", label="LSTMCell_sigmoid")



plt.title("Energy variance: 10x10 spins, 1D RNN model", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Energy variance', fontsize = 25)
plt.legend()
plt.show()
print("\n")

# %% [markdown]
# ### exp2-1-2 10x10和2D RNN 比較

# %%
import tensorflow as tf
from Training1DRNN_2DTFIM import run_2DTFIM

Energy_SimpRNN_elu, varEnergy_SimpRNN_elu        = run_2DTFIM(RNNtype = 0, activationType = 0, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
# Out:
# WARNING:tensorflow:From /home/yhc/tfpip/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.SimpleRNNCell'>
# activation Functions <function elu at 0x7fca4a79d9d8>
# mean(E): -109.13433244312078, var(E): 211.58731326406053, #samples 25, #Step 0
#
#
# mean(E): -110.81476839071723, var(E): 252.85699141082767, #samples 25, #Step 10
#
#
# mean(E): -127.8876703837831, var(E): 351.77216928661403, #samples 25, #Step 20
#
#
# mean(E): -138.8330374626689, var(E): 310.86238193016953, #samples 25, #Step 30
#
#
# mean(E): -148.07871933477355, var(E): 117.36512207981613, #samples 25, #Step 40
#
#
# mean(E): -158.5149556054998, var(E): 221.43822919709558, #samples 25, #Step 50
#
#
# ...

# %%
# spins = 10x10
import tensorflow as tf
from Training2DRNN_2DTFIM import run_2DTFIM

RNNEnergy1010, varRNNEnergy1010 = run_2DTFIM(numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, numsamples = 25, learningrate = 1e-4, seed = 333)
# Out:
# mean(E): -78.64189748992872, var(E): 132.76114010236253, #samples 25, #Step 0
#
#
# mean(E): -95.77284542118034, var(E): 245.75328621667242, #samples 25, #Step 10
#
#
# mean(E): -116.51086706522318, var(E): 113.82041515176861, #samples 25, #Step 20
#
#
# mean(E): -138.9147920668995, var(E): 95.25277439869441, #samples 25, #Step 30
#
#
# mean(E): -140.18849265450038, var(E): 110.93454790455098, #samples 25, #Step 40
#
#
# mean(E): -145.4465229210502, var(E): 116.29404753759204, #samples 25, #Step 50
#
#
# mean(E): -149.80016697173846, var(E): 58.126738872334975, #samples 25, #Step 60
#
#
# mean(E): -153.45205820479632, var(E): 84.23259434842234, #samples 25, #Step 70
#
#
# mean(E): -155.87078251459204, var(E): 95.00993349359598, #samples 25, #Step 80
#
#
# mean(E): -158.66401380729002, var(E): 39.74425288304576, #samples 25, #Step 90
#
#
# mean(E): -162.4902865912069, var(E): 127.35499706578531, #samples 25, #Step 100
#
#
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

# 能量震盪收斂圖
rcParams['axes.labelsize']  = 20 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 25
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25

      
fig, ax = plt.subplots(figsize=(32, 10))
ax.plot(np.arange(1, len(Energy_SimpRNN_elu)+1), Energy_SimpRNN_elu, "vb-", label="1D-RNN model (vanilla RNN)")
ax.plot(np.arange(1, len(RNNEnergy1010)+1), RNNEnergy1010, "vr-",  label="2D-RNN model (Tensorized RNN)")


plt.title("Energy prediction: 10x10 spins, 1D-RNN model (vanilla RNN) vs 2D-RNN model (Tensorized RNN)", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Predicted local Energy', fontsize = 25)
ax.set_xscale('log')
plt.legend()
plt.show()
print("\n")

# %%
# Variacnce plot
# spin = 10z10
rcParams['axes.labelsize']  = 40 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 25 # 圖標的大小
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25


fig, ax = plt.subplots(figsize=(32,10))
ax.semilogy(np.arange(1, len(Energy_SimpRNN_elu)+1), varEnergy_SimpRNN_elu, "vb-", label="1D-RNN model (vanilla RNN)")
ax.semilogy(np.arange(1, len(RNNEnergy1010)+1), varRNNEnergy1010, "vr-",  label="2D-RNN model (Tensorized RNN)")

plt.title("Energy variance: 10x10 spins, 1D-RNN model (vanilla RNN) vs 2D-RNN model (Tensorized RNN)", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Energy variance', fontsize = 25)
plt.legend()
plt.show()
print("\n")

# %% [markdown]
# ### 實驗2-2-1. 25x25 spins, RNNtype, activate function

# %%
# 25x25, SimpleRNNCell 
import tensorflow as tf
from Training1DRNN_2DTFIM import run_2DTFIM

Energy_SimpRNN_elu, varEnergy_SimpRNN_elu                 = run_2DTFIM(RNNtype = 0, activationType = 0, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_SimpRNN_relu, varEnergy_SimpRNN_relu               = run_2DTFIM(RNNtype = 0, activationType = 1, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.SimpleRNNCell'>
# activation Functions <function elu at 0x7fca4a79d9d8>
# mean(E): -674.1171804373093, var(E): 1557.267064600133, #samples 25, #Step 0
#
#
# mean(E): -716.2037593179714, var(E): 2181.319908533618, #samples 25, #Step 10
#
#
# mean(E): -810.298901042062, var(E): 1403.0320329563488, #samples 25, #Step 20
#
#
# mean(E): -894.8540079450254, var(E): 1715.4069754727648, #samples 25, #Step 30
#
#
# mean(E): -964.4364439849804, var(E): 886.830180750324, #samples 25, #Step 40
#
#
# mean(E): -1051.0779348205306, var(E): 1489.7670067725892, #samples 25, #Step 50
#
#
# mean(E): -1111.5654122569736, var(E): 641.0425221004095, #samples 25, #Step 60
#
#
# mean(E): -1162.6598634631946, var(E): 898.1825087736765, #samples 25, #Step 70
#
#
# mean(E): -1187.1109789757058, var(E): 775.0978882291037, #samples 25, #Step 80
#
#
# mean(E): -1220.6557492099084, var(E): 396.38076798516477, #samples 25, #Step 90
#
#
# ...

# %%
Energy_SimpRNN_exponential, varEnergy_SimpRNN_exponential = run_2DTFIM(RNNtype = 0, activationType = 2, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_SimpRNN_sigmoid, varEnergy_SimpRNN_sigmoid         = run_2DTFIM(RNNtype = 0, activationType = 3, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.SimpleRNNCell'>
# activation Functions <function exponential at 0x7fca4a7a0400>
# mean(E): -674.1171804373093, var(E): 1557.267064600133, #samples 25, #Step 0
#
#
# mean(E): -716.316613205668, var(E): 2176.54481860545, #samples 25, #Step 10
#
#
# mean(E): -809.6440252883808, var(E): 1359.6123490637317, #samples 25, #Step 20
#
#
# mean(E): -894.2888254053644, var(E): 1743.5076846854886, #samples 25, #Step 30
#
#
# mean(E): -964.3806051231775, var(E): 888.3493652671066, #samples 25, #Step 40
#
#
# mean(E): -1051.1019076356697, var(E): 1508.510223018647, #samples 25, #Step 50
#
#
# mean(E): -1111.9246584603272, var(E): 663.1519540585567, #samples 25, #Step 60
#
#
# mean(E): -1162.5455173487412, var(E): 899.8248183008882, #samples 25, #Step 70
#
#
# mean(E): -1187.3540420566244, var(E): 777.1163148490909, #samples 25, #Step 80
#
#
# mean(E): -1220.6753265616067, var(E): 396.9036643922202, #samples 25, #Step 90
#
#
# ...

# %%
import tensorflow as tf
from Training1DRNN_2DTFIM import run_2DTFIM

Energy_GRUCell_elu, varEnergy_GRUCell_elu                 = run_2DTFIM(RNNtype = 1, activationType = 0, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_GRUCell_relu, varEnergy_GRUCell_relu               = run_2DTFIM(RNNtype = 1, activationType = 1, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_GRUCell_exponential, varEnergy_GRUCell_exponential = run_2DTFIM(RNNtype = 1, activationType = 2, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_GRUCell_sigmoid, varEnergy_GRUCell_sigmoid         = run_2DTFIM(RNNtype = 1, activationType = 3, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.GRUCell'>
# activation Functions <function elu at 0x7fca4a79d9d8>
# mean(E): -652.58341325377, var(E): 860.2137375586254, #samples 25, #Step 0
#
#
# mean(E): -632.4472699031896, var(E): 1266.255348490883, #samples 25, #Step 10
#
#
# mean(E): -645.7373355632586, var(E): 740.3009128917234, #samples 25, #Step 20
#
#
# mean(E): -636.4185171290918, var(E): 884.4837813427413, #samples 25, #Step 30
#
#
# mean(E): -654.4006922958978, var(E): 1042.0478175103008, #samples 25, #Step 40
#
#
# mean(E): -641.0022108429743, var(E): 1070.876290333517, #samples 25, #Step 50
#
#
# mean(E): -645.2837862188329, var(E): 1368.4387522011841, #samples 25, #Step 60
#
#
# mean(E): -651.1198331794653, var(E): 1230.4613996328515, #samples 25, #Step 70
#
#
# mean(E): -639.8739140121071, var(E): 1089.0361343976783, #samples 25, #Step 80
#
#
# mean(E): -670.6635762614578, var(E): 1668.8722434569959, #samples 25, #Step 90
#
#
# ...

# %%
import tensorflow as tf
from Training1DRNN_2DTFIM import run_2DTFIM

Energy_LSTMCell_elu, varEnergy_LSTM_elu                 = run_2DTFIM(RNNtype = 2, activationType = 0, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_LSTMCell_relu, varEnergy_LSTM_relu               = run_2DTFIM(RNNtype = 2, activationType = 1, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_LSTMCell_exponential, varEnergy_LSTM_exponential = run_2DTFIM(RNNtype = 2, activationType = 2, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
Energy_LSTMCell_sigmoid, varEnergy_LSTM_sigmoid         = run_2DTFIM(RNNtype = 2, activationType = 3, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.LSTMCell'>
# activation Functions <function elu at 0x7fca4a79d9d8>
# mean(E): -640.8264987750412, var(E): 868.3607719318586, #samples 25, #Step 0
#
#
# mean(E): -621.2511579176952, var(E): 1025.3313302645793, #samples 25, #Step 10
#
#
# mean(E): -634.2632643416727, var(E): 657.3353240887316, #samples 25, #Step 20
#
#
# mean(E): -621.2754611065587, var(E): 609.4102764417253, #samples 25, #Step 30
#
#
# mean(E): -638.995835933982, var(E): 1121.240891895717, #samples 25, #Step 40
#
#
# mean(E): -623.1196571605349, var(E): 833.0118178962515, #samples 25, #Step 50
#
#
# mean(E): -625.7200853488406, var(E): 1608.7358682392578, #samples 25, #Step 60
#
#
# mean(E): -629.490183616008, var(E): 1396.6662394471086, #samples 25, #Step 70
#
#
# mean(E): -614.5354449599497, var(E): 1084.8485504440478, #samples 25, #Step 80
#
#
# mean(E): -638.7989064192769, var(E): 1460.2269483280145, #samples 25, #Step 90
#
#
# ...

# %%
# Simple RNN cell      
import numpy as np
min_Energy_SimpRNN_elu = min(Energy_SimpRNN_elu)
print("25x25 model:")
print('min_Energy_SimpRNN_elu', min_Energy_SimpRNN_elu)

min_Energy_SimpRNN_relu = min(Energy_SimpRNN_relu)
print('min_Energy_SimpRNN_relu', min_Energy_SimpRNN_relu)

min_Energy_SimpRNN_exponential = min(Energy_SimpRNN_exponential)
print('min_Energy_SimpRNN_exponential', min_Energy_SimpRNN_exponential)

min_Energy_SimpRNN_sigmoid = min(Energy_SimpRNN_sigmoid)
print('min_Energy_SimpRNN_sigmoid', min_Energy_SimpRNN_sigmoid)
print('\n')

# GRUCell cell      
import numpy as np

min_Energy_GRUCell_elu = min(Energy_GRUCell_elu)
print('min_Energy_GRUCell_elu', min_Energy_GRUCell_elu)

min_Energy_GRUCell_relu = min(Energy_GRUCell_relu)
print('min_Energy_GRUCell_relu', min_Energy_GRUCell_relu)

min_Energy_GRUCell_exponential = min(Energy_GRUCell_exponential)
print('min_Energy_GRUCell_exponential', min_Energy_GRUCell_exponential)

min_Energy_GRUCell_sigmoid = min(Energy_GRUCell_sigmoid)
print('min_Energy_GRUCell_sigmoid', min_Energy_GRUCell_sigmoid)
print('\n')

# LSTMCell cell      
import numpy as np

min_Energy_LSTMCell_elu = min(Energy_LSTMCell_elu)
print('min_Energy_LSTMCell_elu', min_Energy_LSTMCell_elu)

min_Energy_LSTMCell_relu = min(Energy_LSTMCell_relu)
print('min_Energy_LSTMCell_relu', min_Energy_LSTMCell_relu)

min_Energy_LSTMCell_exponential = min(Energy_LSTMCell_exponential)
print('min_Energy_LSTMCell_exponential', min_Energy_LSTMCell_exponential)

min_Energy_LSTMCell_sigmoid = min(Energy_LSTMCell_sigmoid)
print('min_Energy_LSTMCell_sigmoid', min_Energy_LSTMCell_sigmoid)
print('\n')
# Out:
# 25x25 model:
# min_Energy_SimpRNN_elu -1281.831565906277
# min_Energy_SimpRNN_relu -1281.8445551162756
# min_Energy_SimpRNN_exponential -1281.8363444016152
# min_Energy_SimpRNN_sigmoid -1281.8345011423846
#
#
# min_Energy_GRUCell_elu -1281.6739345003384
# min_Energy_GRUCell_relu -1281.6735078993245
# min_Energy_GRUCell_exponential -1281.6730812698913
# min_Energy_GRUCell_sigmoid -1281.6746559389737
#
#
# min_Energy_LSTMCell_elu -1278.0957728723013
# min_Energy_LSTMCell_relu -1278.0955790138512
# min_Energy_LSTMCell_exponential -1278.0954204056693
# min_Energy_LSTMCell_sigmoid -1278.0959587362108

# %%
import numpy as np
#Computing the ground state energy by taking average over the last 200 iterations
numsamples = 25
print("Energy_SimpRNN_elu=", np.mean(Energy_SimpRNN_elu[-200:]), "+-", np.sqrt(np.max(varEnergy_SimpRNN_elu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_SimpRNN_relu=", np.mean(Energy_SimpRNN_relu[-200:]), "+-", np.sqrt(np.max(varEnergy_SimpRNN_relu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_SimpRNN_exponential=", np.mean(Energy_SimpRNN_exponential[-200:]), "+-", np.sqrt(np.max(varEnergy_SimpRNN_exponential[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_SimpRNN_sigmoid=", np.mean(Energy_SimpRNN_sigmoid[-200:]), "+-", np.sqrt(np.max(varEnergy_SimpRNN_sigmoid[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("\n")

print("Energy_GRUCell_elu=", np.mean(Energy_GRUCell_elu[-200:]), "+-", np.sqrt(np.max(varEnergy_GRUCell_elu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_GRUCell_relu=", np.mean(Energy_GRUCell_relu[-200:]), "+-", np.sqrt(np.max(varEnergy_GRUCell_relu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_GRUCell_exponential=", np.mean(Energy_GRUCell_exponential[-200:]), "+-", np.sqrt(np.max(varEnergy_GRUCell_exponential[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_GRUCell_sigmoid=", np.mean(Energy_GRUCell_sigmoid[-200:]), "+-", np.sqrt(np.max(varEnergy_GRUCell_sigmoid[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("\n")

print("Energy_LSTMCell_elu=", np.mean(Energy_LSTMCell_elu[-200:]), "+-", np.sqrt(np.max(varEnergy_LSTM_elu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_LSTMCell_relu=", np.mean(Energy_LSTMCell_relu[-200:]), "+-", np.sqrt(np.max(varEnergy_LSTM_relu[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_LSTMCell_exponential=", np.mean(Energy_LSTMCell_exponential[-200:]), "+-", np.sqrt(np.max(varEnergy_LSTM_exponential[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("Energy_LSTMCell_sigmoid=", np.mean(Energy_LSTMCell_sigmoid[-200:]), "+-", np.sqrt(np.max(varEnergy_LSTM_sigmoid[-200:])/(numsamples*200))) #We use np.max(varRNNEnergy[-200:]) to estimate an upper bound on the error
print("\n")
# Out:
# Energy_SimpRNN_elu= -1278.905726719192 +- 0.08454270689995838
# Energy_SimpRNN_relu= -1278.9063561828725 +- 0.084507691808532
# Energy_SimpRNN_exponential= -1278.908141125022 +- 0.08455069830853483
# Energy_SimpRNN_sigmoid= -1278.9065780843885 +- 0.08484320315731497
#
#
# Energy_GRUCell_elu= -1278.7849790064583 +- 0.08544282132026035
# Energy_GRUCell_relu= -1278.7836024630844 +- 0.08543522884342591
# Energy_GRUCell_exponential= -1278.7845203185884 +- 0.08543670601657848
# Energy_GRUCell_sigmoid= -1278.7846046410912 +- 0.08543770526796787
#
#
# Energy_LSTMCell_elu= -1274.92696883822 +- 0.10511648581148106
# Energy_LSTMCell_relu= -1274.9315890478442 +- 0.10510901919022426
# Energy_LSTMCell_exponential= -1274.9311475183615 +- 0.10510657205983726
# Energy_LSTMCell_sigmoid= -1274.927528778803 +- 0.10508954170324177

# %% [markdown]
# ### 實驗2-2-1 結果圖

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# 能量震盪收斂圖
rcParams['axes.labelsize']  = 20 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 20
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25

      
fig, ax = plt.subplots(figsize=(30, 10))
ax.plot(np.arange(1, len(Energy_SimpRNN_elu)+1), Energy_SimpRNN_elu, "vb--", label="SimpleRNN_elu")
ax.plot(np.arange(1, len(Energy_SimpRNN_relu)+1), Energy_SimpRNN_relu, "vb--",  label="SimpleRNN_sigmoid")
ax.plot(np.arange(1, len(Energy_SimpRNN_exponential)+1), Energy_SimpRNN_exponential, "vb--", label="SimpleRNN_exponential")
ax.plot(np.arange(1, len(Energy_SimpRNN_sigmoid)+1), Energy_SimpRNN_sigmoid, "vb--", label="SimpleRNN_sigmoid")

ax.plot(np.arange(1, len(Energy_GRUCell_elu)+1), Energy_GRUCell_elu, "sr:", label="GRUCell_elu")
ax.plot(np.arange(1, len(Energy_GRUCell_relu)+1), Energy_GRUCell_relu, "sr:",  label="GRUCell_sigmoid")
ax.plot(np.arange(1, len(Energy_GRUCell_exponential)+1), Energy_GRUCell_exponential, "sr:", label="GRUCell_exponential")
ax.plot(np.arange(1, len(Energy_GRUCell_sigmoid)+1), Energy_GRUCell_sigmoid, "sr:", label="GRUCell_sigmoid")

ax.plot(np.arange(1, len(Energy_LSTMCell_elu)+1), Energy_LSTMCell_elu, "og-", label="LSTMCell_elu")
ax.plot(np.arange(1, len(Energy_LSTMCell_relu)+1), Energy_LSTMCell_relu, "og-",  label="LSTMCell_relu")
ax.plot(np.arange(1, len(Energy_LSTMCell_exponential)+1), Energy_LSTMCell_exponential, "og-", label="LSTMCell_exponential")
ax.plot(np.arange(1, len(Energy_LSTMCell_sigmoid)+1), Energy_LSTMCell_sigmoid, "og-", label="LSTMCell_sigmoid")


plt.title("Energy prediction: 25x25 spins, 1D RNN model", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Predicted local Energy', fontsize = 25)
ax.set_xscale('log')
plt.legend()
plt.show()
print("\n")

# %%
# Variacnce plot
# spin = 40x40
rcParams['axes.labelsize']  = 40 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 15 # 圖標的大小
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25


fig, ax = plt.subplots(figsize=(30,10))
ax.semilogy(np.arange(1, len(Energy_SimpRNN_elu)+1), varEnergy_SimpRNN_elu, "vb--", label="SimpleRNN_elu")
ax.semilogy(np.arange(1, len(Energy_SimpRNN_relu)+1), varEnergy_SimpRNN_relu, "vb--",  label="SimpleRNN_sigmoid")
ax.semilogy(np.arange(1, len(Energy_SimpRNN_exponential)+1), varEnergy_SimpRNN_exponential, "vb--", label="SimpleRNN_exponential")
ax.semilogy(np.arange(1, len(Energy_SimpRNN_sigmoid)+1), varEnergy_SimpRNN_sigmoid, "vb--", label="SimpleRNN_sigmoid")

ax.semilogy(np.arange(1, len(Energy_GRUCell_elu)+1), varEnergy_GRUCell_elu, "sr:", label="GRUCell_elu")
ax.semilogy(np.arange(1, len(Energy_GRUCell_relu)+1), varEnergy_GRUCell_relu, "sr:",  label="GRUCell_sigmoid")
ax.semilogy(np.arange(1, len(Energy_GRUCell_exponential)+1), varEnergy_GRUCell_exponential, "sr:", label="GRUCell_exponential")
ax.semilogy(np.arange(1, len(Energy_GRUCell_sigmoid)+1), Energy_GRUCell_sigmoid, "sr:", label="GRUCell_sigmoid")

ax.semilogy(np.arange(1, len(Energy_LSTMCell_elu)+1), varEnergy_LSTM_elu, "og-", label="LSTMCell_elu")
ax.semilogy(np.arange(1, len(Energy_LSTMCell_relu)+1), varEnergy_LSTM_relu, "og-",  label="LSTMCell_relu")
ax.semilogy(np.arange(1, len(Energy_LSTMCell_exponential)+1), varEnergy_LSTM_exponential, "og-", label="LSTMCell_exponential")
ax.semilogy(np.arange(1, len(Energy_LSTMCell_sigmoid)+1), varEnergy_LSTM_sigmoid, "og-", label="LSTMCell_sigmoid")



plt.title("Energy variance: 25x25 spins, 1D RNN model", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Energy variance', fontsize = 25)
plt.legend()
plt.show()
print("\n")

# %% [markdown]
# ### exp2-2-2 25x25和2D RNN 比較

# %%
# spins = 25x25
# 2D RNN
import tensorflow as tf
from Training2DRNN_2DTFIM import run_2DTFIM

RNNEnergy2525, varRNNEnergy2525 = run_2DTFIM(numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, numsamples = 25, learningrate = 1e-4, seed = 333)
# Out:
# mean(E): -556.3406948199594, var(E): 1339.0719212425415, #samples 25, #Step 0
#
#
# mean(E): -878.6735610016163, var(E): 1545.1101912428335, #samples 25, #Step 10
#
#
# mean(E): -998.6531251416159, var(E): 550.1729577710715, #samples 25, #Step 20
#
#
# mean(E): -1060.4472461090475, var(E): 632.1360179775506, #samples 25, #Step 30
#
#
# mean(E): -1094.3531422098192, var(E): 525.1029106303298, #samples 25, #Step 40
#
#
# mean(E): -1125.9375634741207, var(E): 367.8271153362482, #samples 25, #Step 50
#
#
# mean(E): -1143.9713340037897, var(E): 712.8071456065439, #samples 25, #Step 60
#
#
# mean(E): -1159.135936630256, var(E): 296.7019909037606, #samples 25, #Step 70
#
#
# mean(E): -1159.0812476209207, var(E): 248.19085916178213, #samples 25, #Step 80
#
#
# mean(E): -1165.9644785212165, var(E): 349.91151082926154, #samples 25, #Step 90
#
#
# mean(E): -1173.4131341729124, var(E): 333.3581651256258, #samples 25, #Step 100
#
#
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

# 能量震盪收斂圖
rcParams['axes.labelsize']  = 20 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 25
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25

      
fig, ax = plt.subplots(figsize=(32, 10))
ax.plot(np.arange(1, len(Energy_SimpRNN_exponential)+1), Energy_SimpRNN_exponential, "vb-", label="1D-RNN model (vanilla RNN)")
ax.plot(np.arange(1, len(RNNEnergy2525)+1), RNNEnergy2525, "vr-",  label="2D-RNN model (Tensorized RNN)")


plt.title("Energy prediction: 25x25 spins, 1D-RNN model (vanilla RNN) vs 2D-RNN model (Tensorized RNN)", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Predicted local Energy', fontsize = 25)
ax.set_xscale('log')
plt.legend()
plt.show()
print("\n")

# %%
# Variacnce plot
# spin = 20z20
rcParams['axes.labelsize']  = 40 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 25 # 圖標的大小
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25


fig, ax = plt.subplots(figsize=(32,10))
ax.semilogy(np.arange(1, len(Energy_SimpRNN_exponential)+1), varEnergy_SimpRNN_exponential, "vb-", label="1D-RNN model (vanilla RNN)")
ax.semilogy(np.arange(1, len(RNNEnergy2525)+1), varRNNEnergy2525, "vr-",  label="2D-RNN model (Tensorized RNN)")

plt.title("Energy variance: 25x25 spins, 1D-RNN model (vanilla RNN) vs 2D-RNN model (Tensorized RNN)", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Energy variance', fontsize = 25)
plt.legend()
plt.show()
print("\n")

# %% [markdown]
# ### exp2-3 10x10 vs SQA

# %%
#10x10 1D RNN
import tensorflow as tf
from Training1DRNN_2DTFIM import run_2DTFIM
import time
sec1 = time.time()
Energy_SimpRNN_elu, varEnergy_SimpRNN_elu    = run_2DTFIM(RNNtype = 0, activationType = 0, numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
sec2 = time.time()
print("cost time =", sec2-sec1)
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.SimpleRNNCell'>
# activation Functions <function elu at 0x7f1f9584b488>
# mean(E): -109.13433244312078, var(E): 211.58731326406053, #samples 25, #Step 0
#
#
# mean(E): -110.80486711296429, var(E): 253.2566913420221, #samples 25, #Step 10
#
#
# mean(E): -127.89464915427972, var(E): 351.22412910078964, #samples 25, #Step 20
#
#
# mean(E): -138.83158426711643, var(E): 311.03862479669027, #samples 25, #Step 30
#
#
# mean(E): -148.0873315978797, var(E): 117.51269290463169, #samples 25, #Step 40
#
#
# mean(E): -158.51562282861576, var(E): 221.54787185976767, #samples 25, #Step 50
#
#
# mean(E): -168.21405967351674, var(E): 145.7884207279284, #samples 25, #Step 60
#
#
# mean(E): -172.65143066363487, var(E): 64.06176629375209, #samples 25, #Step 70
#
#
# mean(E): -176.7378122214495, var(E): 42.676392641591846, #samples 25, #Step 80
#
#
# mean(E): -181.09730944728813, var(E): 64.24173424879785, #samples 25, #Step 90
#
#
# ...

# %%
# 10x10 2D RNN
import tensorflow as tf
from Training2DRNN_2DTFIM import run_2DTFIM
import time
sec1 = time.time()
RNNEnergy1010, varRNNEnergy1010 = run_2DTFIM(numsteps = 1000, systemsize_x = 10, systemsize_y = 10, Bx = 1, num_units = 40, numsamples = 25, learningrate = 1e-4, seed = 333)
sec2 = time.time()
print("cost time =", sec2-sec1)
# Out:
# mean(E): -78.64189748992872, var(E): 132.76114010236253, #samples 25, #Step 0
#
#
# mean(E): -95.77284542118034, var(E): 245.75328621667242, #samples 25, #Step 10
#
#
# mean(E): -116.51086706522318, var(E): 113.82041515176861, #samples 25, #Step 20
#
#
# mean(E): -138.9147920668995, var(E): 95.25277439869441, #samples 25, #Step 30
#
#
# mean(E): -140.18849265450038, var(E): 110.93454790455098, #samples 25, #Step 40
#
#
# mean(E): -145.4465229210502, var(E): 116.29404753759204, #samples 25, #Step 50
#
#
# mean(E): -149.80016697173846, var(E): 58.126738872334975, #samples 25, #Step 60
#
#
# mean(E): -153.45205820479632, var(E): 84.23259434842234, #samples 25, #Step 70
#
#
# mean(E): -155.87078251459204, var(E): 95.00993349359598, #samples 25, #Step 80
#
#
# mean(E): -158.66401380729002, var(E): 39.74425288304576, #samples 25, #Step 90
#
#
# mean(E): -162.4902865912069, var(E): 127.35499706578531, #samples 25, #Step 100
#
#
# ...

# %%
# 25x25, 1D RNN
import tensorflow as tf
from Training1DRNN_2DTFIM import run_2DTFIM
import time
sec1 = time.time()
Energy_SimpRNN_exponential, varEnergy_SimpRNN_exponential = run_2DTFIM(RNNtype = 0, activationType = 2, numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, num_layers = 1, numsamples = 25, learningrate = 1e-4, seed = 333)
sec2 = time.time()
print("cost time =", sec2-sec1)
# Out:
# cell type:  <class 'tensorflow.python.keras.layers.recurrent.SimpleRNNCell'>
# activation Functions <function exponential at 0x7f1f9584be18>
# mean(E): -674.1171804373093, var(E): 1557.267064600133, #samples 25, #Step 0
#
#
# mean(E): -716.2360708636265, var(E): 2182.0348748869287, #samples 25, #Step 10
#
#
# mean(E): -810.4143547693071, var(E): 1388.0291040090492, #samples 25, #Step 20
#
#
# mean(E): -894.071197984377, var(E): 1735.0201912482237, #samples 25, #Step 30
#
#
# mean(E): -964.4071321831867, var(E): 889.0343652559214, #samples 25, #Step 40
#
#
# mean(E): -1051.1147417117143, var(E): 1512.1601443808258, #samples 25, #Step 50
#
#
# mean(E): -1111.8818749860675, var(E): 669.483003075653, #samples 25, #Step 60
#
#
# mean(E): -1162.5770263497056, var(E): 894.4349143713683, #samples 25, #Step 70
#
#
# mean(E): -1187.3431152559126, var(E): 776.9528218032593, #samples 25, #Step 80
#
#
# mean(E): -1220.7008654302406, var(E): 397.4513303069305, #samples 25, #Step 90
#
#
# ...

# %%
# spins = 25x25
# 2D RNN
import tensorflow as tf
from Training2DRNN_2DTFIM import run_2DTFIM
import time
sec1 = time.time()
RNNEnergy2525, varRNNEnergy2525 = run_2DTFIM(numsteps = 1000, systemsize_x = 25, systemsize_y = 25, Bx = 1, num_units = 40, numsamples = 25, learningrate = 1e-4, seed = 333)
sec2 = time.time()
print("cost time =", sec2-sec1)
# Out:
# mean(E): -556.3406948199594, var(E): 1339.0719212425415, #samples 25, #Step 0
#
#
# mean(E): -878.6735610016163, var(E): 1545.1101912428335, #samples 25, #Step 10
#
#
# mean(E): -998.6531251416159, var(E): 550.1729577710715, #samples 25, #Step 20
#
#
# mean(E): -1060.4472461090475, var(E): 632.1360179775506, #samples 25, #Step 30
#
#
# mean(E): -1094.3531422098192, var(E): 525.1029106303298, #samples 25, #Step 40
#
#
# mean(E): -1125.9375634741207, var(E): 367.8271153362482, #samples 25, #Step 50
#
#
# mean(E): -1143.9713340037897, var(E): 712.8071456065439, #samples 25, #Step 60
#
#
# mean(E): -1159.135936630256, var(E): 296.7019909037606, #samples 25, #Step 70
#
#
# mean(E): -1159.0812476209207, var(E): 248.19085916178213, #samples 25, #Step 80
#
#
# mean(E): -1165.9644785212165, var(E): 349.91151082926154, #samples 25, #Step 90
#
#
# mean(E): -1173.4131341729124, var(E): 333.3581651256258, #samples 25, #Step 100
#
#
# ...

# %%
import numpy as np
sqa1010 = np.array([22, -64, -102, -112, -122, -130, -126, -130, -130, -134, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138, -134, -138])
sqa2525 = np.array([94, -378, -672, -790, -846, -938, -968, -984, -1010, -1026, -1042, -1044, -1074, -1074, -1082, -1094, -1090, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102, -1098, -1102])

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

# 能量震盪收斂圖
rcParams['axes.labelsize']  = 20 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 25
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25

      
fig, ax = plt.subplots(figsize=(25, 10))
ax.plot(np.arange(1, len(Energy_SimpRNN_elu)+1), Energy_SimpRNN_elu, "vb-", label="Best 1D RNN model (vanilla)")
ax.plot(np.arange(1, len(RNNEnergy1010)+1), RNNEnergy1010, "vr-",  label="2D-RNN model (Tensorized RNN)")
ax.plot(np.arange(1, len(sqa1010)+1), sqa1010, "vg-",  label="SQA")


plt.title("Energy prediction: 10x10 spins, 1D-RNN model vs 2D-RNN model vs SQA", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Predicted local Energy', fontsize = 25)
ax.set_xscale('log')
plt.legend()
plt.show()
print("\n")

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

# 能量震盪收斂圖
rcParams['axes.labelsize']  = 20 #座標上的label大小
rcParams['font.serif']      = ['Computer Modern']
rcParams['font.size']       = 30
rcParams['legend.fontsize'] = 25
rcParams['xtick.labelsize'] = 25
rcParams['ytick.labelsize'] = 25

      
fig, ax = plt.subplots(figsize=(25, 10))
ax.plot(np.arange(1, len(Energy_SimpRNN_exponential)+1), Energy_SimpRNN_exponential, "vb-", label="Best 1D RNN model (vanilla)")
ax.plot(np.arange(1, len(RNNEnergy2525)+1), RNNEnergy2525, "vr-",  label="2D-RNN model (Tensorized RNN)")
ax.plot(np.arange(1, len(sqa2525)+1), sqa2525, "vg-",  label="SQA")


plt.title("Energy prediction: 25x25 spins, 1D-RNN model vs 2D-RNN model vs SQA", fontsize = 36)
ax.set_xlabel(r'Training step', fontsize = 25)
ax.set_ylabel('Predicted local Energy', fontsize = 25)
ax.set_xscale('log')
plt.legend()
plt.show()
print("\n")

# %%
print("cost time:")
print("10x10, 1D RNN model cost time = 31.945314168930054")
print("10x10, 2D RNN model cost time = 40.94314122200012")
print("25x25, 1D RNN model cost time = 291.72423243522644")
print("10x10, 2D RNN model cost time = 317.2645981311798")
# Out:
# cost time:
# 10x10, 1D RNN model cost time = 31.945314168930054
# 10x10, 2D RNN model cost time = 40.94314122200012
# 25x25, 1D RNN model cost time = 291.72423243522644
# 10x10, 2D RNN model cost time = 317.2645981311798
